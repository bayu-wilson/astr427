# %% [markdown]
# # Monday May 21 2018
#
# ### Lecture notes for ASTR 427 with Professor Tom Quinn
#
# ### Bayu Wilson

# %% [markdown]
# # Part 1
#
# Let's think about what goes on in a processor. ALU is logic unit that communicates with instruction decode unit (INST Decode). There's also registers for local data. Then there's a memory unit that talks to the outside world.

# %%
# import pycuda.driver as cuda
#!tar xfz pycuda-VERSION.tar.gz
#!pip install pycuda
# Out:
# ...
#     100% |████████████████████████████████| 1.6MB 789kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 7.3MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 573kB 1.7MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for pycuda ... error
#   Complete output from command /Users/bayuwilson/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/dc/ls44gwz52z13328qkf2xyhgm0000gn/T/pip-build-0lar6llz/pycuda/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /var/folders/dc/ls44gwz52z13328qkf2xyhgm0000gn/T/tmpf0nbcwe6pip-wheel- --python-tag cp35:
#   ***************************************************************
#   *** WARNING: nvcc not in path.
#   *** May need to set CUDA_INC_DIR for installation to succeed.
#   ***************************************************************
# ...
